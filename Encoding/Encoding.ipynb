# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2=pd.read_csv(r"C:\Users\bhagy\OneDrive\Desktop\practice\Emp_Data.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   EmpID    29 non-null     int64
#  1   FName    29 non-null     object
#  2   LName    29 non-null     object
#  3   Gender   29 non-null     object
#  4   Age      29 non-null     int64
#  5   EMail    29 non-null     object
#  6   Salary   29 non-null     int64
#  7   LOC      29 non-null     object
#  8   MGR_ID   29 non-null     int64
#  9   DEPT_ID  29 non-null     int64
# dtypes: int64(5), object(5)
# memory usage: 2.4+ KB

# %%
df2.head()
# Out:
#     EmpID     FName     LName Gender  Age                         EMail  \
# 0  677509      Lois    Walker      F   22       lois.walker@hotmail.com
# 1  940761    Brenda  Robinson      F   43     brenda.robinson@gmail.com
# 2  428945       Joe  Robinson      M   32        joe.robinson@gmail.com
# 3  408351     Diane       Jon      F   25         diane.evans@yahoo.com
# 4  193819  Benjamin   Russell      M   45  benjamin.russell@charter.net
#
#    Salary       LOC  MGR_ID  DEPT_ID
# 0  168251    DALLAS  677509       10
# 1   51063   CHICAGO  940761       10
# 2   50155   CHICAGO  372661       10
# 3  180294  NEW YORK  217421       20
# 4  117642    DALLAS  408951       20

# %%
from sklearn.preprocessing import LabelEncoder
df2['Gender']=LabelEncoder().fit_transform(df2['Gender'])

df2.head()
# Out:
#     EmpID     FName     LName  Gender  Age                         EMail  \
# 0  677509      Lois    Walker       0   22       lois.walker@hotmail.com
# 1  940761    Brenda  Robinson       0   43     brenda.robinson@gmail.com
# 2  428945       Joe  Robinson       1   32        joe.robinson@gmail.com
# 3  408351     Diane       Jon       0   25         diane.evans@yahoo.com
# 4  193819  Benjamin   Russell       1   45  benjamin.russell@charter.net
#
#    Salary       LOC  MGR_ID  DEPT_ID
# 0  168251    DALLAS  677509       10
# 1   51063   CHICAGO  940761       10
# 2   50155   CHICAGO  372661       10
# 3  180294  NEW YORK  217421       20
# 4  117642    DALLAS  408951       20

# %%
from sklearn.preprocessing import LabelEncoder
df2['Gender']=LabelEncoder().fit_transform(df2['Gender'])
df2['LOC']=LabelEncoder().fit_transform(df2['LOC'])
df2.head()
# Out:
#     EmpID     FName     LName  Gender  Age                         EMail  \
# 0  677509      Lois    Walker       0   22       lois.walker@hotmail.com
# 1  940761    Brenda  Robinson       0   43     brenda.robinson@gmail.com
# 2  428945       Joe  Robinson       1   32        joe.robinson@gmail.com
# 3  408351     Diane       Jon       0   25         diane.evans@yahoo.com
# 4  193819  Benjamin   Russell       1   45  benjamin.russell@charter.net
#
#    Salary  LOC  MGR_ID  DEPT_ID
# 0  168251    1  677509       10
# 1   51063    0  940761       10
# 2   50155    0  372661       10
# 3  180294    4  217421       20
# 4  117642    1  408951       20

# %%
df2[['LOC']].value_counts()
# Out:
# LOC
# 0      9
# 1      8
# 4      4
# 5      4
# 2      2
# 3      2
# Name: count, dtype: int64

# %%
import pandas as pd
df2=pd.read_csv(r"C:\Users\bhagy\OneDrive\Desktop\practice\Emp_Data.csv")
df2.shape
dummy1=pd.get_dummies(df2,columns=['LOC'])
dummy1
# Out:
#       EmpID     FName        LName Gender  Age                         EMail  \
# 0    677509      Lois       Walker      F   22       lois.walker@hotmail.com
# 1    940761    Brenda     Robinson      F   43     brenda.robinson@gmail.com
# 2    428945       Joe     Robinson      M   32        joe.robinson@gmail.com
# 3    408351     Diane          Jon      F   25         diane.evans@yahoo.com
# 4    193819  Benjamin      Russell      M   45  benjamin.russell@charter.net
# 5    499687   Patrick       Bailey      M   43        patrick.bailey@aol.com
# 6    539712     Nancy        Baker      F   23            nancy.baker@bp.com
# 7    380086     Carol       Murphy      F   31        carol.murphy@gmail.com
# 8    477616   Frances        Young      F   21       frances.young@gmail.com
# 9    162402     Diana     Peterson      F   24  diana.peterson@hotmail.co.uk
# 10   231469     Ralph       Flores      M   35        ralph.flores@yahoo.com
# ...
